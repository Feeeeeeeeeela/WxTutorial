# %% [markdown]
# ### Mixér barev ve wxGlade
# Pro ukázku si vytvoříme míxér barev z názorných příkladů, kde jsme kód psali ručně a jsme již seznámeni s problematikou.

# %% [markdown]
# ![míxér barev](img/wxgladefinal_screen.png)

# %% [markdown]
# Na začátku si vytvoříme základní frame.  <br>
# V pracovním okně by se nám měl vytvořit v hlavní aplikaci frame a automaticky se vytvoří jeho základní sizer:
# ![1](img/wxglade1_screen.png)

# %% [markdown]
# Nyní vytvoříme položky hlavního sizeru:
# 1. Sider obsahující wx.StaticText popisující inputy barev
# 2. Sider obsahující samotné inputy wx.SpinCtrl
# 3. Panel pro zobrazování barvy
# 4. Sizer s tlačítkem pro update a wx.TextCtrl pro zobrazení hex čísla barvy
#
# ![2](img/wxglade2_screen.png)

# %% [markdown]
# Nyní nastavíme syzery, aby se přirozeně roztahovaly a zmenšovaly.
# Nastavení najdeme v kolonce `Layout` vedle `Common`, kde nastavujeme základní parametry objektu (typy, jméno).
# ![3](img/wxglade3_screen.png)

# %% [markdown]
# ### 1. Proportion <br>
# Určuje nastavenou velikost mezi objekty jednoho sizeru. Pro ukázku v našem případě:
#
# První a druhý sizer nastavíme na `0`, protože nechceme, aby se neměnila jejich výška, protože vzhledově potřebujeme, aby zaplňovali pouze jeden řádek.
#
# Dalšími objekty je panel a sizer s tlačítkem a textem. Poslední sizer obsahuje text a tlačítko, které může měnit i výškové parametry, tudíš mu dáme parametr 1. Velikost při roshatování panelu nedělá žádné grafické problémy, takže mu můžeme dat největší místo, tudíš 2.
# ### 2. Border <br>
# Slouží k odsazení od ostatních objektů a framu samotného. Prvně nastavíme velikost odstazení v `px`. Potom zaškrtneme z jaké strany chceme objekt odsadit.
# ### 3. Alignment <br>
# Slouží k samotnému chování při měnění velikosti. V našem případě všechny sizery nastavíme na `wx.Expand`.

# %% [markdown]
# ## Nyní k nastavení objektů v sizerech:
# V prvních dvou sizerech cheme mít 3 stejně velké objekty. Toho docílíme, že jim nastavíme stejný parametr proporce `1` (kdybychom nastavili všem 0, tak objekty budou přímo za sebou nikoliv stejně rozprostření po framu). Je důležité nepoužít `wx.EXPAND`, protože by se každý objekt rozšiřoval sám. To by mělo za následek, že by se při zmenšování okna zmenšoval jen objekt tomu nejblíže.
# ![4](img/wxglade4_screen.png)

# %% [markdown]
# Objekty v posledním sizeru nastavíme:
# ![5](img/wxglade5_screen.png)
# * Tlačítko <br>
# Proporci nastavíme na 1, protože tlačítko se může roztahovat aji do výšky. Dále nastavíme `wx.EXPAND`.
# * wx.StaticText <br>
# Ze stejného důvodu jako v objektech v prvních dvou sizerech nastavíme proporci na `0`. Pro roztažení do krajů nastavíme opět `wx.EXPAND`.

# %% [markdown]
# ## Přejmenování tlačítek
# Pro lenost využijeme logiky z příkladu, takže bude potřeba přejmenovat objekty, které využíváme.

# %% [markdown]
# ![6](img/wxglade6_screen.png)

# %% [markdown]
# Ještě doupravíme max. hodnotu `wx.TextCtrl` na 255.

# %% [markdown]
# # Vygenerujeme samotný kód
# Klikneme na `Generate Source` ve spodní částí aplikace nebo v liště ve `file`. Kód se vygeneruje v uložišti, kde máme uloženou práci (pokud nemáme, tak bude potřeba program uložit. Programy se ukládají s příponou `wxg`, který při spuštění přímo spustí `wxGlade`). Kód se uloží jako `wxglade_out.py`.

# %%
#!/usr/bin/env python
# -*- coding: UTF-8 -*-
#
# generated by wxGlade 0.9.6 on Wed Nov 18 19:35:31 2020
#

import wx

# begin wxGlade: dependencies
# end wxGlade

# begin wxGlade: extracode
# end wxGlade


class MyFrame(wx.Frame):
    def __init__(self, *args, **kwds):
        # begin wxGlade: MyFrame.__init__
        kwds["style"] = kwds.get("style", 0) | wx.DEFAULT_FRAME_STYLE
        wx.Frame.__init__(self, *args, **kwds)
        self.SetSize((366, 316))
        self.first = wx.SpinCtrl(self, wx.ID_ANY, "0", min=0, max=255)
        self.second = wx.SpinCtrl(self, wx.ID_ANY, "0", min=0, max=255)
        self.third = wx.SpinCtrl(self, wx.ID_ANY, "0", min=0, max=255)
        self.cpnl = wx.Panel(self, wx.ID_ANY)
        self.btn = wx.Button(self, wx.ID_ANY, "Change Color")
        self.idhex = wx.TextCtrl(self, wx.ID_ANY, "", style=wx.TE_CENTRE)

        self.__set_properties()
        self.__do_layout()
        # end wxGlade

    def __set_properties(self):
        # begin wxGlade: MyFrame.__set_properties
        self.SetTitle("Color mixer")
        # end wxGlade

    def __do_layout(self):
        # begin wxGlade: MyFrame.__do_layout
        mainsizer = wx.BoxSizer(wx.VERTICAL)
        sizer_3 = wx.BoxSizer(wx.VERTICAL)
        sizer_2 = wx.BoxSizer(wx.HORIZONTAL)
        sizer_1 = wx.BoxSizer(wx.HORIZONTAL)
        label_1 = wx.StaticText(self, wx.ID_ANY, "Red:")
        sizer_1.Add(label_1, 1, 0, 0)
        label_2 = wx.StaticText(self, wx.ID_ANY, "Green:")
        sizer_1.Add(label_2, 1, 0, 0)
        label_3 = wx.StaticText(self, wx.ID_ANY, "Blue:")
        sizer_1.Add(label_3, 1, 0, 0)
        mainsizer.Add(sizer_1, 0, wx.EXPAND, 0)
        sizer_2.Add(self.first, 1, 0, 0)
        sizer_2.Add(self.second, 1, 0, 0)
        sizer_2.Add(self.third, 1, 0, 0)
        mainsizer.Add(sizer_2, 0, wx.EXPAND, 0)
        mainsizer.Add(self.cpnl, 2, wx.EXPAND, 0)
        sizer_3.Add(self.btn, 1, wx.EXPAND, 0)
        sizer_3.Add(self.idhex, 0, wx.EXPAND, 0)
        mainsizer.Add(sizer_3, 1, wx.EXPAND, 0)
        self.SetSizer(mainsizer)
        self.Layout()
        # end wxGlade

# end of class MyFrame

class MyApp(wx.App):
    def OnInit(self):
        self.frame = MyFrame(None, wx.ID_ANY, "")
        self.SetTopWindow(self.frame)
        self.frame.Show()
        return True

# end of class MyApp

if __name__ == "__main__":
    app = MyApp(0)
    app.MainLoop()

# %% [markdown]
# Logiku můžeme jednodušše zkopírovat z příkladu. Stejné platí i pro `Bind` jednoho tlačítka. <br>
# Musíme si dát pozor na jména tlačítek, protože `wxGlade` je automaticky nastavuje s atributem `self`. <br>
# Pro úplnost ještě přidáme barvu panelu při zapnutí na `Black`.

# %%
#!/usr/bin/env python
# -*- coding: UTF-8 -*-
#
# generated by wxGlade 0.9.6 on Wed Nov 18 19:35:31 2020
#

import wx

# begin wxGlade: dependencies
# end wxGlade

# begin wxGlade: extracode
# end wxGlade


class MyFrame(wx.Frame):
    def __init__(self, *args, **kwds):
        # begin wxGlade: MyFrame.__init__
        kwds["style"] = kwds.get("style", 0) | wx.DEFAULT_FRAME_STYLE
        wx.Frame.__init__(self, *args, **kwds)
        self.SetSize((366, 316))
        self.first = wx.SpinCtrl(self, wx.ID_ANY, "0", min=0, max=100)
        self.second = wx.SpinCtrl(self, wx.ID_ANY, "0", min=0, max=100)
        self.third = wx.SpinCtrl(self, wx.ID_ANY, "0", min=0, max=100)
        self.cpnl = wx.Panel(self, wx.ID_ANY)
        self.btn = wx.Button(self, wx.ID_ANY, "Change Color")
        self.idhex = wx.TextCtrl(self, wx.ID_ANY, "", style=wx.TE_CENTRE)
        
        self.cpnl.SetBackgroundColour("black")
        
        self.Bind(wx.EVT_BUTTON, self.onpress, self.btn)

        self.__set_properties()
        self.__do_layout()
        # end wxGlade
        
    def onpress(self, event):
        rn = self.first.GetValue()
        gn = self.second.GetValue()
        bn = self.third.GetValue()
        hexnumber = '#%02x%02x%02x' % (rn, gn, bn)
        self.cpnl.SetBackgroundColour(hexnumber)
        self.cpnl.Refresh()
        self.idhex.SetValue(hexnumber)

    def __set_properties(self):
        # begin wxGlade: MyFrame.__set_properties
        self.SetTitle("Color mixer")
        # end wxGlade

    def __do_layout(self):
        # begin wxGlade: MyFrame.__do_layout
        mainsizer = wx.BoxSizer(wx.VERTICAL)
        sizer_3 = wx.BoxSizer(wx.VERTICAL)
        sizer_2 = wx.BoxSizer(wx.HORIZONTAL)
        sizer_1 = wx.BoxSizer(wx.HORIZONTAL)
        label_1 = wx.StaticText(self, wx.ID_ANY, "Red:")
        sizer_1.Add(label_1, 1, 0, 0)
        label_2 = wx.StaticText(self, wx.ID_ANY, "Green:")
        sizer_1.Add(label_2, 1, 0, 0)
        label_3 = wx.StaticText(self, wx.ID_ANY, "Blue:")
        sizer_1.Add(label_3, 1, 0, 0)
        mainsizer.Add(sizer_1, 0, wx.EXPAND, 0)
        sizer_2.Add(self.first, 1, 0, 0)
        sizer_2.Add(self.second, 1, 0, 0)
        sizer_2.Add(self.third, 1, 0, 0)
        mainsizer.Add(sizer_2, 0, wx.EXPAND, 0)
        mainsizer.Add(self.cpnl, 2, wx.EXPAND, 0)
        sizer_3.Add(self.btn, 1, wx.EXPAND, 0)
        sizer_3.Add(self.idhex, 0, wx.EXPAND, 0)
        mainsizer.Add(sizer_3, 1, wx.EXPAND, 0)
        self.SetSizer(mainsizer)
        self.Layout()
        # end wxGlade

# end of class MyFrame

class MyApp(wx.App):
    def OnInit(self):
        self.frame = MyFrame(None, wx.ID_ANY, "")
        self.SetTopWindow(self.frame)
        self.frame.Show()
        return True

# end of class MyApp

if __name__ == "__main__":
    app = MyApp(0)
    app.MainLoop()
